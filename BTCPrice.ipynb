# %% [markdown]
# <a href="https://colab.research.google.com/github/ikevins/MachineLearning-BTCPrice/blob/main/BTCPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("BTCPrice.csv")

# Store the data
df['Date'] = pd.to_datetime(df['Date'])

# Calculate price average
df['Average'] = ((df['High'] + df['Low']) / 2)

print(df['Average'])
# Out:
# 0         460.298004
# 1         434.981994
# 2         406.183502
# 3         406.589493
# 4         402.803497
#             ...
# 3307    27949.257812
# 3308    27921.416015
# 3309    27646.016601
# 3310    27508.750976
# 3311    27019.729492
# Name: Average, Length: 3312, dtype: float64

# %%
# It is important to note the Bitcoin trades 24/7, therefore doesn't have "open"
# or "close" prices

# Plot the historical open price
plt.figure(figsize=(15, 5))
plt.plot(df['Date'], df['Average'])
plt.title('Bitcoin Price Over Time')
plt.xlabel('Date')
plt.ylabel('Daily Average')
# Out:
# Text(0, 0.5, 'Daily Average')
